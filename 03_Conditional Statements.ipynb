# %% [markdown]
# Decision Making

# %%
# Syntax:
# if condition:
# statements...

# %%
# Given the age of the person, check if they are eligibile to vote.
#if age is atleast 20, then they are eligible, else not

Age = 25
if Age >= 20:
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Eligible to vote

# %%
Age = 10
if Age >= 20:
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Not eligible to vote

# %%
# Q2. Take the password from the user. If it matches "hello@123" then print "Welcome".

password = input("Enter your password:")
if password == "hello@123":
  print("Welcome")
# Out:
# Enter your password:hello@123
# Welcome

# %%
#if-else
age = 19
if age >= 20:
 print("Eligible to vote")
else:
 print("Not Eligible")
# Out:
# Not Eligible

# %%
age = 22
if age >= 20:
 print("Eligible to vote")
else:
 print("Not Eligible")
# Out:
# Eligible to vote

# %%
# Q3. Take the password from the user.
# If it matches "hello@123" then print "Welcome".
# Else, print "Invalid Password"

password = input("Enter your password:")
if password == "hello@123":
  print("Welcome")
else:
  print("Invalid password")
# Out:
# Enter your password:hello@123
# Welcome

# %%
password = input("Enter your password:")
if password == "hello@123":
  print("Welcome")
else:
  print("Invalid password")
# Out:
# Enter your password:hdsjjdshhjxc
# Invalid password

# %%
if 2> 3:
 print("A")
else:
 print("B")
print("C")
# Out:
# B
# C

# %%
if 2 < 3:
 print("A")
else:
 print("B")
print("C")
# Out:
# A
# C

# %%
from re import M

# marks =>
# marks < 30 --> "Low"
# marks between 30 and 70 --> "Avg"
# marks > 70 --> "High"
# using if-else only


Marks = int(input("Enter your Marks:"))
if Marks <= 30:
  print("Low")
else:
  if Marks <= 70:
    print("Avg")
  else:
    print("High")
# Out:
# Enter your Marks:15
# Low

# %%
Marks = int(input("Enter your Marks:"))
if Marks <= 30:
  print("Low")
else:
  if Marks <= 70:
    print("Avg")
  else:
    print("High")
# Out:
# Enter your Marks:70
# Avg

# %%
Marks = int(input("Enter your Marks:"))
if Marks <= 30:
  print("Low")
else:
  if Marks <= 70:
    print("Avg")
  else:
    print("High")
# Out:
# Enter your Marks:95
# High

# %%
#  else if ==> elif
if 2 > 3:
 print("A")
else:
 print("B")
# Out:
# B

# %%
#  else if ==> elif
if 2 < 3:
 print("A")
else:
 print("B")
# Out:
# A

# %%
if 2 < 3:
 print("A")
elif 5 > 4:
 print("B")
else:
 print("C")
# Out:
# A

# %%
if 2 > 3:
 print("A")
elif 5 > 4:
 print("B")
else:
 print("C")
# Out:
# B

# %%
if 2 > 3:
 print("A")
elif 5 < 4:
 print("B")
else:
 print("C")
# Out:
# C

# %%
# elif
# marks =>
# marks < 30 --> "Low"
# marks between 30 and 70 --> "Avg"
# marks > 70 --> "High"

Marks = int(input("Enter your marks:"))
if Marks < 30:
  print("Low")
elif Marks < 70:
  print("Avg")
else:
  print("High")
# Out:
# Enter your marks:30
# Avg

# %%
Marks = int(input("Enter your marks:"))
if Marks < 30:
  print("Low")
elif Marks < 70:
  print("Avg")
else:
  print("High")
# Out:
# Enter your marks:70
# High

# %%
Marks = int(input("Enter your marks:"))
if Marks < 30:
  print("Low")
elif Marks < 70:
  print("Avg")
else:
  print("High")
# Out:
# Enter your marks:25
# Low

# %%
city = "Pune"
if city == "Pune":
 print("Welcome to Pune")
# Out:
# Welcome to Pune
