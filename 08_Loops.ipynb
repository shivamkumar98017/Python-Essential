# %% [markdown]
# List:-

# %%
marks = [90, 86, 95, 83, 70]

# %%
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
a = [45, "Shivam kumar", 6.8, True]

# %%
print(a)
# Out:
# [45, 'Shivam kumar', 6.8, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %%
students=[]
print(students)
# Out:
# []

# %% [markdown]
# Indexing

# %%
#indexing starts at 0
print(marks)
# Out:
# [90, 86, 95, 83, 70]

# %%
marks[0]
# Out:
# 90

# %%
marks[2]
# Out:
# 95

# %%
marks[3]
# Out:
# 83

# %%
n=len(marks)

# %%
print(n)
# Out:
# 5

# %%
marks[n-1]
# Out:
# 70

# %%
marks[n-2]
# Out:
# 83

# %%
marks[n-3]
# Out:
# 95

# %%
marks[-1]
# Out:
# 70

# %%
marks[-2]
# Out:
# 83

# %% [markdown]
# Iterating over a list

# %%
n = len(marks)
print(n)
# Out:
# 5

# %%
marks[0]
# Out:
# 90

# %%
marks[1]
# Out:
# 86

# %%
for i in range(n):
 print(marks[i])
# Out:
# 90
# 86
# 95
# 83
# 70

# %%
for elem in marks:
 print(elem)
# Out:
# 90
# 86
# 95
# 83
# 70

# %%
#Write a code to print the elements present at even indexes
for i in range(n):
 if i%2 == 0:
  print(marks[i])
# Out:
# 90
# 95
# 70

# %%
#Write a code to print all the even elements
for i in range(n):
 if marks[i]%2 == 0:
  print(marks[i])
# Out:
# 90
# 86
# 70

# %%
for elem in marks:
 if elem%2 == 0:
  print(elem)
# Out:
# 90
# 86
# 70

# %%
# What is printed?
numbers = [5,10,15]
for i in range(len(numbers)):
 print(numbers[i])
# Out:
# 5
# 10
# 15

# %%
# What is the output?
marks = [60,70,80,90]
print(max(marks))
# Out:
# 90

# %%
#Write a code to find the sum of all the elements of the list.
marks = [60,70,80,90]
sm = 0
for elem in marks:
 sm = sm + elem
print(sm)
# Out:
# 300

# %%
marks = [60,70,80,90]
n = len(marks)
sm = 0
for elem in marks:
 sm = sm + elem
print(sm/n)
# Out:
# 75.0

# %%
numbers = [5, 10, 15]
numbers[1] = numbers[0] + numbers[2]
print(numbers)
print(sum(numbers))
# Out:
# [5, 20, 15]
# 40

# %%
marks = [50, 60, 70, 80]
for i in range(len(marks)):
 marks[i] = marks[i] + 5
print(marks)
# Out:
# [55, 65, 75, 85]

# %%
data = [2, 4, 6]
for i in range(len(data)):
 print(i, data[i])
# Out:
# 0 2
# 1 4
# 2 6

# %%
numbers = [8, 2, 5, 1]
print(min(numbers))
print(max(numbers))
print(max(numbers) - min(numbers))
# Out:
# 1
# 8
# 7

# %%
items = [1, 2, 3]
for i in range(len(items)):
 items[i] = items[i] * 2
print(sum(items))
# Out:
# 12

# %%
numbers = [10, 20, 30]
print(numbers[-1])
numbers[-1] = 100
print(numbers)
# Out:
# 30
# [10, 20, 100]

# %%
nums = [2, 4, 6, 8]
count = 0
for n in nums:
 if n > 4:
  count += 1
print(count)
# Out:
# 2

# %%
marks = [80, 75, 90]
highest = max(marks)
for m in marks:
 print(highest - m)
# Out:
# 10
# 15
# 0

# %%
numbers = [3, 5, 7]
result = 1
for n in numbers:
 result = result * n
print(result)
# Out:
# 105

# %%
data = [10, 20, 30]
for i in range(len(data)):
 data[i] = data[i] + 10
print(max(data))
print(min(data))
# Out:
# 40
# 20

# %%
names = ["Amit", "Neha", "Raj"]
longest = names[0]
for name in names:
 if len(name) > len(longest):
  longest = name
print(longest)
# Out:
# Amit

# %%
nums = [2, 4, 6]
nums[0] = nums[2]
nums[2] = nums[1]
print(nums)
# Out:
# [6, 4, 4]

# %%
marks = [65, 75, 85]
total = 0
for m in marks:
 if m >= 70:
  total += m
print(total)
# Out:
# 160

# %%
numbers = [1, 2, 3, 4]
for i in range(len(numbers)):
 numbers[i] = numbers[i] + i
print(numbers)
# Out:
# [1, 3, 5, 7]
