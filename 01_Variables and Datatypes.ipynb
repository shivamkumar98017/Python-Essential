# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print(5+3)
# Out:
# 8

# %%
print("Python")
print("Sql")
# Out:
# Python
# Sql

# %%
print("A")
print("B")
print("C")
print("D")
# Out:
# A
# B
# C
# D

# %% [markdown]
# Comments

# %%
# This code print Shivam on the screen
print("Shivam")
# Out:
# Shivam

# %% [markdown]
# Variables

# %%
Name = "Shivam"
City = "Motihari"
Id = 234


print(Name)
print(Id)
print(City)
# Out:
# Shivam
# 234
# Motihari

# %%
#Variable naming rules
# 1. Start: Alphabet , _
# 2. Middle or end --> Alphabet, _, digits



# student_name --> yes
# _marks --> yes
# City --> yes
# State5 --> yes
# 4city --> no
# student-name --> no

# %%
# variable_name = value

# %%
college = "RCOEM"
college = "IIT Bombay"
print(college)
# Out:
# IIT Bombay

# %%
college = "RCOEM"
print(college)
college = "IIT Bombay"
print(college)
# Out:
# RCOEM
# IIT Bombay

# %% [markdown]
# Data Types

# %%
# 1. Integer --> int
# eg: 50, 4, -6, 0, 22
# 2. Float --> decimal (also called double)
# eg: 5.7, -4.5, 3.6, 2.0
# 3. String (text data) --> str
# "Shivam", "Motihari" ,  "Shivam Kumar"
# 4. Boolean --> True/False --> bool

# %%
# "4" --> str
# 5 --> int
# True --> bool
# length = 6.7 --> float

# %%
type("4")
# Out:
# str

# %%
type(5)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(6.7)
# Out:
# float

# %% [markdown]
# Taking input from the user

# %%
name = "shivam"

# %%
# input()

# %%
name = input()
# Out:
# shivam

# %%
print(name)
# Out:
# shivam

# %%
name = input("Enter your name:")
# Out:
# Enter your name:Ayush

# %%
print(name)
# Out:
# Ayush

# %%
#  Q. Take two int as input from the user and print their sum
A = int(input("Enter a number:"))
B = int(input("Enter another number:"))
sum = A+B
print(sum)
# Out:
# Enter a number:3
# Enter another number:4
# 7

# %% [markdown]
# string concatenation

# %%
4+5
# Out:
# 9

# %%
"4"+"5"
# Out:
# '45'

# %%
"A"+"B"
# Out:
# 'AB'

# %%
#  input() --> it is always taken as string

# %% [markdown]
# Type Casting

# %%
age = "20"
new_age = int(age) #typecasting
type(new_age)
# Out:
# int

# %%
type(age)
# Out:
# str

# %%
# Q. Take year of birth as input and print the age.
Birth_year = int(input())
age = 2026-Birth_year
print("Your age is",age,".")
# Out:
# 2008
# Your age is 18 .

# %%
#  Q. Take length and breadth of the rectangle as input and print its area.
Length = float(input())
Breadth = float(input())
Area = Length*Breadth
print("Area is",Area,"sq.units.")
# Out:
# 4.5
# 56
# Area is 252.0 sq.units.

# %%
#  Q. Take length and breadth of the rectangle as input and print its area.
Length = float(input())
Breadth = float(input())
Area = Length*Breadth
print("Area is",Area,"sq.units.")
# Out:
# 45
# 65
# Area is 2925.0 sq.units.

# %%
#  Q. Take the name, age and height (in inches) of the student as input and print them.
Name = input()
Age = float(input())
Height = float(input())
print("Your name is",Name,".")
print("Your age is",Age,"years.")
print("Your height is",Height,"inches.")
# Out:
# shivam kumar
# 18
# 500
# Your name is shivam kumar .
# Your age is 18.0 years.
# Your height is 500.0 inches.
